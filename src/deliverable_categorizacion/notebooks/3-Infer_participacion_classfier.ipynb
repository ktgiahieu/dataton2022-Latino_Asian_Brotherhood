# %%
# !pip install transformers sentence_transformers seaborn pickle5 umap-learn

# %%
# !pip3 install setfit
# %pip uninstall tensorflow -y

# %%
# !rm -rf /content/dataton2022-Latino_Asian_Brotherhood
# !git clone -b khuong_categorize https://ktgiahieu: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@github.com/ktgiahieu/dataton2022-Latino_Asian_Brotherhood.git

# %%
# !\cp dataton2022-Latino_Asian_Brotherhood/notebooks/few_shot_learning/* .

# %% [markdown]
# # Train

# %%
import random
import torch
import numpy as np
import os
def set_seed(seed=1234):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True
set_seed(2022)

# %%
from datasets import load_dataset
from sentence_transformers.losses import CosineSimilarityLoss
from setfit import SetFitModel, SetFitTrainer

# Load SetFit model 
model = SetFitModel.from_pretrained('../input/trained-setfix-sector/trained_setfix')

# %% [markdown]
# # Infer

# %%
import pandas as pd
import numpy as np
client_news_df = pd.read_csv('/kaggle/input/dataton-2022/clientes_noticias.csv')[['nit', 'news_url_absolute','news_id']]
news_df = pd.read_csv('/kaggle/input/dataton-2022/noticias.csv')


client_news_df = client_news_df.merge(news_df, on='news_id')
client_news_df['text'] = client_news_df.news_title + '. ' + client_news_df.news_text_content
client_news_df['text'] = client_news_df['text'].apply(lambda x: x[:10000])
client_news_df.shape
# Out:
# (74709, 9)

# %%
# preds = model(client_news_df.text.values)
# client_news_df['preds'] = preds
preds_proba = model.predict_proba(client_news_df.text.values)
# Out:
# Batches:   0%|          | 0/2335 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1463/2913383603.py in <module>
#       2 # client_news_df['preds'] = preds
#       3 preds_proba = model.predict_proba(client_news_df.text.values)
# ----> 4 for i, l in enumerate(labels):
#       5     client_news_df[l] = preds_proba[:,i]
#       6 client_news_df
#
# NameError: name 'labels' is not defined

# %%
df = pd.read_csv('../input/dataton-participacion-label/dataton2022-Latino_Asian_Brotherhood/code/matched_news_group.csv')
df.rename(columns={'group':'label_text'}, inplace=True)
df['text'] = df['news_title'] + '. ' + df['news_text_content']
labels = df.label_text.unique()

# %%
for i, l in enumerate(labels):
    client_news_df[l] = preds_proba[:,i]
client_news_df
# Out:
#              nit                                news_url_absolute_x  \
# 0      900378212  https://www.bluradio.com/economia/precio-dolar...
# 1      900378212  https://www.semana.com/economia/macroeconomia/...
# 2      860034313  https://www.semana.com/economia/macroeconomia/...
# 3      900378212  https://elcomercio.pe/respuestas/que/gustavo-p...
# 4      900166896  https://elcomercio.pe/respuestas/que/gustavo-p...
# ...          ...                                                ...
# 74704  800230209  https://www.laopinion.com.co/economia/en-cucut...
# 74705  890209174  https://www.laopinion.com.co/economia/en-cucut...
# 74706  830069311  https://www.laopinion.com.co/economia/en-cucut...
# 74707  830130106  https://www.laopinion.com.co/economia/en-cucut...
# 74708  890110188  https://www.laopinion.com.co/economia/en-cucut...
#
#          news_id                                news_url_absolute_y  \
# 0      news10006  https://www.bluradio.com/economia/precio-dolar...
# 1      news10011  https://www.semana.com/economia/macroeconomia/...
# 2      news10011  https://www.semana.com/economia/macroeconomia/...
# 3      news10015  https://elcomercio.pe/respuestas/que/gustavo-p...
# 4      news10015  https://elcomercio.pe/respuestas/que/gustavo-p...
# ...          ...                                                ...
# 74704  news99997  https://www.laopinion.com.co/economia/en-cucut...
# 74705  news99997  https://www.laopinion.com.co/economia/en-cucut...
# 74708  0.007174  0.012927  0.006034  0.008017  0.004098  0.006583  0.003958
#
#        group_47   group_6  group_42
# 0      0.004109  0.005149  0.001707
# 1      0.021432  0.010641  0.004992
# 2      0.021432  0.010641  0.004992
# 3      0.001454  0.007176  0.000480
# 4      0.001454  0.007176  0.000480
# ...         ...       ...       ...
# 74704  0.010785  0.035789  0.003124
# 74705  0.010785  0.035789  0.003124
# 74706  0.010785  0.035789  0.003124
# 74707  0.010785  0.035789  0.003124
# 74708  0.010785  0.035789  0.003124
#
# [74709 rows x 49 columns]

# %%
client_news_df['preds'] = np.argmax(preds_proba,1)

labels_map_inverse = {}
for i, l in enumerate(labels):
    labels_map_inverse[i]=l
client_news_df['pred_group'] = client_news_df['preds'].replace(labels_map_inverse)

client_news_df.head()
# Out:
#          nit                                news_url_absolute_x    news_id  \
# 0  900378212  https://www.bluradio.com/economia/precio-dolar...  news10006
# 1  900378212  https://www.semana.com/economia/macroeconomia/...  news10011
# 2  860034313  https://www.semana.com/economia/macroeconomia/...  news10011
# 3  900378212  https://elcomercio.pe/respuestas/que/gustavo-p...  news10015
# 4  900166896  https://elcomercio.pe/respuestas/que/gustavo-p...  news10015
#
#                                  news_url_absolute_y news_init_date  \
# 0  https://www.bluradio.com/economia/precio-dolar...     2022-07-30
# 1  https://www.semana.com/economia/macroeconomia/...     2022-07-30
# 2  https://www.semana.com/economia/macroeconomia/...     2022-07-30
# 3  https://elcomercio.pe/respuestas/que/gustavo-p...     2022-07-30
# 4  https://elcomercio.pe/respuestas/que/gustavo-p...     2022-07-30
#
#   news_final_date                                         news_title  \
# 0      2022-08-14  Precio dolar hoy: la cotizacion de la divisa a...
# 1      2022-08-14  Es cierto: El presidente Gustavo Petro quiere ...
# 2      2022-08-14  Es cierto: El presidente Gustavo Petro quiere ...
# 3      2022-08-14  Gustavo Petro: ?Que dice el informe final de s...
# 4      2022-08-14  Gustavo Petro: ?Que dice el informe final de s...
#
#                                    news_text_content  \
# 0  Este martes, 2 de agosto, el dolar alcanzo un ...
# 1  No hay nada mas permanente que lo temporal y a...
# 2  No hay nada mas permanente que lo temporal y a...
# 3  El equipo de empalme del gobierno del presiden...
# 4  El equipo de empalme del gobierno del presiden...
#
#                                                 text  preds  ...  group_35  \
# 0  Precio dolar hoy: la cotizacion de la divisa a...     27  ...  0.002634
# 1  Es cierto: El presidente Gustavo Petro quiere ...      5  ...  0.020259
# 2  Es cierto: El presidente Gustavo Petro quiere ...      5  ...  0.020259
# 3  Gustavo Petro: ?Que dice el informe final de s...     21  ...  0.001440
# 4  Gustavo Petro: ?Que dice el informe final de s...     21  ...  0.001440
#
#    group_48  group_33  group_38   group_5   group_4  group_47   group_6  \
# 0  0.003016  0.003350  0.003213  0.001485  0.004005  0.004109  0.005149
# 1  0.007194  0.005707  0.004062  0.006475  0.014887  0.021432  0.010641
# 2  0.007194  0.005707  0.004062  0.006475  0.014887  0.021432  0.010641
# 3  0.001580  0.002454  0.002170  0.000827  0.000921  0.001454  0.007176
# 4  0.001580  0.002454  0.002170  0.000827  0.000921  0.001454  0.007176
#
#    group_42  pred_group
# 0  0.001707    group_21
# 1  0.004992    group_25
# 2  0.004992    group_25
# 3  0.000480    group_36
# 4  0.000480    group_36
#
# [5 rows x 50 columns]

# %%
client_news_df.to_csv('pred_news_group.csv', index=False)
